# %%
import requests
import json
import pandas as pd
# 네이버 API 인증 정보
client_id = "x_45StwzjCiPnscCfTqJ"
client_secret = "aOhY7CBjXw"

# 공통 헤더
headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret': client_secret
}

# 검색 함수 정의
def search_books(query):
    url = "https://openapi.naver.com/v1/search/book.json"
    
    # 쿼리 파라미터 설정
    payload = {
        'query': query,
        'display': 10,
        'sort': 'sim'
    }

    # API 요청
    res = requests.get(url, params=payload, headers=headers)

    # 응답 코드 확인
    if res.status_code == 200:
        items = res.json()['items']
        return items
    else:
        print("Error:", res.status_code)
        return []

# 결과 파싱 예시
books = search_books("파이썬")
with open('data/books.json', 'w', encoding='utf-8') as f:
    json.dump(books, f, ensure_ascii=False, indent=2)
# 파싱해서 출력
for book in books:
    print("제목:", book['title'])
    print("저자:", book['author'])
    print("출판사:", book['publisher'])
    print("링크:", book['link'])
    print("-" * 40)
df = pd.read_json('data/books.json')
df
# Out:
# 제목: 혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임, 맵, AI 챗봇 만들기|저자 직강 유튜브 강의, 오픈 채팅 제공)
# 저자: 문현일
# 출판사: 한빛미디어
# 링크: https://search.shopping.naver.com/book/catalog/52859338841
# ----------------------------------------
# 제목: 혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
# 저자: 윤인성
# 출판사: 한빛미디어
# 링크: https://search.shopping.naver.com/book/catalog/32507605957
# ----------------------------------------
# 제목: Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)
# 저자: 박응용
# 출판사: 이지스퍼블리싱
# 링크: https://search.shopping.naver.com/book/catalog/40354085633
# ----------------------------------------
# 제목: 밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
# 저자: 사이토 고키
# 출판사: 한빛미디어
# 링크: https://search.shopping.naver.com/book/catalog/52615553184
# ----------------------------------------
# 제목: 파이썬
# 저자: 홍의경
# 출판사: 생능출판
# 링크: https://search.shopping.naver.com/book/catalog/32460987987
# ----------------------------------------
# 제목: CODING BASICS PYTHON (파이썬)
# 저자: 김상민^장성식^김일태
# 출판사: 렉스미디어닷넷
# ...

# %%
df.loc[df['discount']>= 20000]

# %%
df.loc[df['publisher']=='인피니티북스']
# Out:
#   title                                               link  \
# 7   파이썬  https://search.shopping.naver.com/book/catalog...
#
#                                                image author  discount  \
# 7  https://shopping-phinf.pstatic.net/main_324891...    천인국     12000
#
#   publisher   pubdate           isbn  \
# 7    인피니티북스  20170830  9791185578330
#
#                                          description
# 7  컴퓨팅 사고(Computational Thinking)는 자넷 윙 교수가 2006년...
