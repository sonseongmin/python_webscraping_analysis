# %%
import requests
import json
import pandas as pd
import os
# 네이버 API 인증 정보
client_id = "x_45StwzjCiPnscCfTqJ"
client_secret = "aOhY7CBjXw"

# 공통 헤더
headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret': client_secret
}
os.makedirs('data',exist_ok=True)
# 검색 함수 정의
def search_shops(query):
    url = "https://openapi.naver.com/v1/search/shop.json"
    
    # 쿼리 파라미터 설정
    payload = {
        'query': query,
        'display': 40,
        'sort': 'sim'
    }

    # API 요청
    res = requests.get(url, params=payload, headers=headers)

    # 응답 코드 확인
    if res.status_code == 200:
        items = res.json()['items']
        return items
    else:
        print("Error:", res.status_code)
        return []


# 결과 파싱 예시
shops = search_shops("신발")
with open('data/shops.json', 'w', encoding='utf-8') as f:
    json.dump(shops, f, ensure_ascii=False, indent=2)
df= pd.read_json('data/shops.json')
df

# %%
area_50000 = df.loc[df['lprice']>50000]
area_50000.loc[df['mallName'] == '네이버','lprice':'brand'].reset_index(drop=True)
# Out:
#    lprice hprice mallName    productId  productType brand
# 0  113900             네이버  35859710618            1   르무통
# 1  109900             네이버  47766065618            1   르무통
# 2  113900             네이버  42787505618            1   르무통
# 3  113900             네이버  40191482618            1   르무통
# 4  170100             네이버  45853441621            1    호카
